# %% [markdown]
# # IntroExt - Model Comparison

# %% [markdown]
# | Metric | Random Forest | XGBoost (Tuned) |
# |---|---|---|
# | Train Accuracy | 93.1% | 92.9% |
# | Test Accuracy | 91.6% | 91.4% |
# | AUC | 0.961 | 0.970 |
# | Train/Test Gap | 1.5% | 1.5% |
#
# **Selected Model: Random Forest**
#
# Random Forest was selected as the final model for deployment due to:
# - Higher test accuracy (91.6%) and AUC (0.961)
# - Balanced feature importance across all 7 features
# - Minimal overfitting with only a 1.5% train/test gap
